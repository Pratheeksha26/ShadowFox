# %% [markdown]
# # **Predicting the Next Word**

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


# Sample data
corpus = [
    "I love programming in Python",
    "Python is a great programming language",
    "I enjoy learning new programming languages",
    "Programming is fun and exciting",
    "I love to solve problems using Python",
    "I am enjoying",
    "Can't believe we came so far"
]

# Convert to lowercase for consistency
corpus = [line.lower() for line in corpus]

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# Create input sequences
input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i + 1]
        input_sequences.append(n_gram_sequence)

# Pad sequences
max_sequence_length = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# Create predictors and labels
X, y = input_sequences[:, :-1], input_sequences[:, -1]  # No need for one-hot encoding

# Build the model
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_length - 1))
model.add(LSTM(150))
model.add(Dropout(0.2))  # Add dropout to reduce overfitting
model.add(Dense(total_words, activation='softmax'))

# Compile the model with sparse categorical cross-entropy
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=100, verbose=1)

# Function to predict the next word
def predict_next_word(text):
    token_list = tokenizer.texts_to_sequences([text.lower()])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length - 1, padding='pre')
    predicted = model.predict(token_list, verbose=0)
    return tokenizer.index_word[np.argmax(predicted)]

# Example usage
input_text = "I love to"
next_word = predict_next_word(input_text)
print(f"The next word prediction for '{input_text}' is: '{next_word}'")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0323 - loss: 3.3662
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.0968 - loss: 3.3607
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.0968 - loss: 3.3528
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.1613 - loss: 3.3446
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.1290 - loss: 3.3359
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.1613 - loss: 3.3275
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.1613 - loss: 3.3192
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.1290 - loss: 3.3052
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.1935 - loss: 3.2953
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.1613 - loss: 3.2809
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.1613 - loss: 3.2662
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.1290 - loss: 3.2547
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.1290 - loss: 3.2328
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.1613 - loss: 3.2143
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1613 - loss: 3.1725
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.0645 - loss: 3.1755
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.0968 - loss: 3.1743
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0968 - loss: 3.1209
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.1290 - loss: 3.1022
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.1290 - loss: 3.1484
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.1935 - loss: 3.0965
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.1935 - loss: 3.0554
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.1935 - loss: 3.0139
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.1935 - loss: 3.0437
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1935 - loss: 3.0323
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.1613 - loss: 2.9658
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2581 - loss: 2.9556
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1935 - loss: 2.9691
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.2581 - loss: 2.8897
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2258 - loss: 2.8819
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.1935 - loss: 2.8262
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2581 - loss: 2.8109
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.2258 - loss: 2.8045
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.2903 - loss: 2.6811
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.2258 - loss: 2.7173
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.2903 - loss: 2.6007
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.2258 - loss: 2.5424
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3226 - loss: 2.4622
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.2903 - loss: 2.4637
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.2903 - loss: 2.4102
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3226 - loss: 2.2580
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3548 - loss: 2.2907
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3548 - loss: 2.1764
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4194 - loss: 2.0628
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4516 - loss: 2.0503
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3226 - loss: 2.0508
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5806 - loss: 1.9105
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5161 - loss: 1.8237
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4516 - loss: 1.7458
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4839 - loss: 1.8281
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5484 - loss: 1.6302
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5806 - loss: 1.6516
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6452 - loss: 1.5653
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6129 - loss: 1.5013
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6774 - loss: 1.4863
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6774 - loss: 1.4206
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.4839 - loss: 1.5192
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7097 - loss: 1.3602
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6129 - loss: 1.4048
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7419 - loss: 1.3319
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.7742 - loss: 1.1916
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7742 - loss: 1.2333
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7097 - loss: 1.2699
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8387 - loss: 1.0849
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8387 - loss: 1.0244
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8710 - loss: 0.9731
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7742 - loss: 1.0012
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8065 - loss: 0.9774
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7419 - loss: 1.0033
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8710 - loss: 0.9573
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8387 - loss: 0.8937
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7419 - loss: 0.9519
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7097 - loss: 0.9968
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8065 - loss: 0.9807
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7742 - loss: 0.8647
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8710 - loss: 0.7803
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8710 - loss: 0.7126
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9032 - loss: 0.7187
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8387 - loss: 0.7673
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8710 - loss: 0.7200
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8710 - loss: 0.7850
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8710 - loss: 0.6310
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8710 - loss: 0.6484
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8710 - loss: 0.6563
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8387 - loss: 0.6629
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9032 - loss: 0.5598
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8387 - loss: 0.6317
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8710 - loss: 0.5397
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9355 - loss: 0.4817
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8710 - loss: 0.5881
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8710 - loss: 0.5296
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8710 - loss: 0.4951
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8710 - loss: 0.5424
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8387 - loss: 0.5244
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9032 - loss: 0.4581
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8710 - loss: 0.4574
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9032 - loss: 0.4535
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9032 - loss: 0.4443
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9355 - loss: 0.4604
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8710 - loss: 0.4710
# The next word prediction for 'I love to' is: 'solve'

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


# Function to preprocess text (lowercase, strip whitespace, remove special characters)
def preprocess_text(corpus):
    corpus = [line.lower().strip() for line in corpus]
    return [line for line in corpus if line]  # Remove empty lines

# Load and preprocess the text file for corpus
with open("/content/1661-0.txt", 'r', encoding='utf-8') as file:
    corpus = file.readlines()

corpus = preprocess_text(corpus)

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# Create input sequences
input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i + 1]
        input_sequences.append(n_gram_sequence)

# Pad sequences
max_sequence_length = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# Create predictors and labels
X, y = input_sequences[:, :-1], input_sequences[:, -1]  # No need for one-hot encoding

# Build the model
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_length - 1))
model.add(LSTM(150))
model.add(Dropout(0.2))  # Add dropout to reduce overfitting
model.add(Dense(total_words, activation='softmax'))

# Compile the model with sparse categorical cross-entropy
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=5, verbose=1)

# Function to predict the next word
def predict_next_word(text):
    token_list = tokenizer.texts_to_sequences([text.lower()])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length - 1, padding='pre')
    predicted = model.predict(token_list, verbose=0)
    return tokenizer.index_word[np.argmax(predicted)]

print(" ")

# Example usage
input_text = "I can’t"
next_word = predict_next_word(input_text)
print(f"The next word prediction for '{input_text}' is: '{next_word}'")

input_text = "she is"
next_word = predict_next_word(input_text)
print(f"The next word prediction for '{input_text}' is: '{next_word}'")
# Out:
# Epoch 1/5
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 292s 91ms/step - accuracy: 0.0576 - loss: 6.5849
# Epoch 2/5
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 359s 113ms/step - accuracy: 0.1113 - loss: 5.6877
# Epoch 3/5
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 333s 105ms/step - accuracy: 0.1441 - loss: 5.2851
# Epoch 4/5
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 309s 97ms/step - accuracy: 0.1622 - loss: 4.9807
# Epoch 5/5
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 300s 90ms/step - accuracy: 0.1791 - loss: 4.7050
#
# The next word prediction for 'I can’t' is: 'have'
# The next word prediction for 'she is' is: 'a'

# %% [markdown]
# # **Correcting the Wrong Spelling**

# %%
from spellchecker import SpellChecker

# Initialize the spell checker
spell = SpellChecker()

# Function to perform autocorrect on user input
def autocorrect(text_input):
    words = text_input.split()

    # Find misspelled words
    misspelled_words = spell.unknown(words)

    # Prepare the output with corrections
    corrected_text = ""
    for word in words:
        if word in misspelled_words:
            # Replace the misspelled word with the best correction
            corrected_word = spell.correction(word)
            corrected_text += corrected_word + " "
        else:
            corrected_text += word + " "

    return corrected_text

# User input
text_input = input("Enter text: ")

# Autocorrect the input
corrected_text = autocorrect(text_input)

# Display the corrected text
print("\nCorrected text:")
print(corrected_text)
# Out:
# Enter text: wronh speling
#
# Corrected text:
# wrong spelling
